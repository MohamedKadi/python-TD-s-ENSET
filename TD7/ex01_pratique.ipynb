# %%
import numpy as np
import pandas as pd
import os

CSV_PATH =os.getcwd() + "\\tp2_data.csv"
df = pd.read_csv(CSV_PATH,sep=';',
    quotechar='"',
    engine='python'
    )
#print(df["Année"])

#df [ 33: 35 ]

#df.loc[0,"taux fertilité j. femmes"]
#df.iloc[0,1]

dfi = df.set_index("Année") 
#print(dfi)

#df.values
#df[["Année"]].values

#create rows
#rows = [{"Année":1960, "taux fertilité j. femmes":4.97929949835611},{"taux fertilité j. femmes":2.97929949835611}]
#pd.DataFrame(rows)

df["sup_50"] = (df["esperance vie"]> 50)
print("df")
# Out:
#     Année  taux fertilité j. femmes  femmes scol. sec.  esperance vie  \
# 0    1960                  4.979299                NaN      52.581916
# 1    1961                  5.003564                NaN      53.075105
# 2    1962                  5.025367                NaN      53.492420
# 3    1963                  5.045551                NaN      54.017514
# 4    1964                  5.056470                NaN      54.687504
# ..    ...                       ...                ...            ...
# 56   2016                  2.444849           65.84860      72.186230
# 57   2017                  2.427295           66.26728      72.391699
# 58   2018                  2.414922           66.26578      72.574415
# 59   2019                  2.401720                NaN      72.763223
# 60   2020                  2.387123                NaN      72.747919
#
#     accès electricité  emission CO2  conso élec per capita  surface foret
# ...
