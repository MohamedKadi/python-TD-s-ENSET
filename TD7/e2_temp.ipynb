# %%
import numpy as np
import pandas as pd
import os

CSV_PATH =os.getcwd() + "\\temperature.csv"
df = pd.read_csv(CSV_PATH)

# %%
print(df.dtypes)
print(type(df))
# Out:
# record_id                              int64
# month                                  int64
# day                                    int64
# year                                   int64
# AverageTemperatureFahr               float64
# AverageTemperatureUncertaintyFahr    float64
# City                                  object
# country_id                            object
# Country                               object
# Latitude                              object
# Longitude                             object
# dtype: object

# %%
df.describe()
