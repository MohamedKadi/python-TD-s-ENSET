# %%
import matplotlib.pyplot as plt
import numpy as np

plt.axis([0,10,0,10])
plt.grid()
x = np.linspace(1,10,50)
#print(x) array 50val
y = x/2
plt.title("title")
plt.xlabel("x labell")
plt.ylabel("y label")
plt.plot(x,y)
plt.show()
